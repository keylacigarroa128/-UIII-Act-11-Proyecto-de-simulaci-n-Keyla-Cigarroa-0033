# %% [markdown]
# <a href="https://colab.research.google.com/github/keylacigarroa128/-UIII-Act-11-Proyecto-de-simulaci-n-Keyla-Cigarroa-0033/blob/main/UIII_Act_11_Proyecto_de_simulaci%C3%B3n_Keyla_Cigarroa_0033.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Keyla Paola Cigarroa Palacios NL = 12 Fecha 26/mayo/2026
#
# ### Estilistas ✂️💇‍♀️

# %%
# --- PROGRAMA DE SIMULACIÓN DE IA: GLAMOUR DATA-ANALYTICS ---

# Al inicio, el diccionario principal empieza completamente vacío
diccionario_estilistas = {}


def registrar_estilista():
    print("\n--- 📝 REGISTRO DE NUEVO ESTILISTA ---")

    # Entrada del nombre que servirá como la LLAVE (Key) principal
    nombre = input("Nombre del estilista: ")

    # Creamos las variables para los valores (Values)
    especialidad = input("Especialidad en color (ej. Balayage): ")
    salon = input("Salón de belleza al que pertenece: ")
    agenda = input("Agenda semanal (ej. Lun-Vie 9-18): ")
    tecnicas = input("Técnicas dominadas: ")
    marcas = input("Marcas aliadas: ")
    premios = input("Premio's o reconocimientos: ")

    # Guardamos los datos dentro del diccionario principal
    # Asociamos el 'nombre' como Key, y un nuevo diccionario como Value
    diccionario_estilistas[nombre] = {
        "Especialidad en color": especialidad,
        "Salón de belleza": salon,
        "Agenda semanal": agenda,
        "Técnicas dominadas": tecnicas,
        "Marcas aliadas": marcas,
        "Premios": premios,
    }

    print(f"\n✅ ¡IA: Estilista '{nombre}' registrado con éxito en el diccionario!")


def mostrar_estilistas():
    print("\n" + "=" * 135)
    print(" 💈 BASE DE DATOS: DIRECTORIO DE ESTILISTAS REGISTRADOS 💈")
    print("=" * 135)

    # REGLA: Si el diccionario está vacío
    if len(diccionario_estilistas) == 0:
        print("La base de datos (Diccionario) está vacía. ¡Registra a alguien primero!")
    else:
        # ENCABEZADO DE LA TABLA ALINEADO
        # Usamos <15, <20, etc. para definir el ancho exacto de cada columna
        encabezado = f"{'Nombre':<15} | {'Especialidad':<20} | {'Salón':<20} | {'Agenda Semanal':<18} | {'Técnicas':<20} | {'Marcas':<18} | {'Premios':<15}"
        print(encabezado)
        print("-" * 135)

        # CICLO FOR: Para recorrer un diccionario usamos .items() que nos da la (Llave, Valor)
        for nombre, datos in diccionario_estilistas.items():
            fila = (
                f"{nombre:<15} | "
                f"{datos['Especialidad en color']:<20} | "
                f"{datos['Salón de belleza']:<20} | "
                f"{datos['Agenda semanal']:<18} | "
                f"{datos['Técnicas dominadas']:<20} | "
                f"{datos['Marcas aliadas']:<18} | "
                f"{datos['Premios']:<15}"
            )
            print(fila)

    print("=" * 135 + "\n")


def simular_ia_recomendacion():
    print("\n--- 🤖 MÓDULO DE IA: ASISTENTE RECOMENDADOR ---")

    if len(diccionario_estilistas) == 0:
        print("IA: No tengo datos en el diccionario para analizar.")
    else:
        print("IA: ¿Qué técnica, marca o especialidad estás buscando hoy?")
        busqueda = input("Introduce una palabra clave (ej. Balayage): ")
        print("\nIA: Procesando diccionarios y buscando coincidencias...")

        encontrado = False

        # Recorremos el diccionario para que la IA analice la información
        for nombre, datos in diccionario_estilistas.items():
            # Evaluamos las condiciones usando IF y operadores lógicos
            if (
                busqueda.lower() in datos["Especialidad en color"].lower()
                or busqueda.lower() in datos["Técnicas dominadas"].lower()
                or busqueda.lower() in datos["Marcas aliadas"].lower()
            ):
                print(
                    f"⭐ ¡RECOMENDACIÓN IA!: Te sugerimos a **{nombre}** en el salón '{datos['Salón de belleza']}'."
                )
                print(f"   Habilidades: {datos['Técnicas dominadas']}")
                print(f"   Agenda disponible: {datos['Agenda semanal']}\n")
                encontrado = True

        if not encontrado:
            print("IA: No encontré estilistas con esa combinación de habilidades.")


# --- MENÚ INTERACTIVO PRINCIPAL (Ciclo While True) ---
while True:
    print("========================================")
    print("      💇 CONSOLA DE INTELIGENCIA ARTIFICIAL 💇")
    print("            'GLAMOUR DATA-ANALYTICS'   ")
    print("========================================")
    print("1. Registrar nuevo estilista")
    print("2. Mostrar tabla de estilistas (Alineada)")
    print("3. Consultar al Asistente de IA (Búsqueda)")
    print("4. Salir del sistema")
    print("========================================")

    opcion = input("Elige una opción (1-4): ")

    # Estructura de control IF, ELIF, ELSE
    if opcion == "1":
        registrar_estilista()
    elif opcion == "2":
        mostrar_estilistas()
    elif opcion == "3":
        simular_ia_recomendacion()
    elif opcion == "4":
        print("\n👋 ¡Gracias por usar la IA de Glamour Data-Analytics! Cerrando sistemas...")
        print("programa realizado por keyla cigarroa Nl = 12}")
        break
    else:
        print("❌ Opción no válida. Por favor, elige un número del 1 al 4.\n")
# Out:
# ...
#       💇 CONSOLA DE INTELIGENCIA ARTIFICIAL 💇
#             'GLAMOUR DATA-ANALYTICS'
# ...
# 1. Registrar nuevo estilista
# 2. Mostrar tabla de estilistas (Alineada)
# 3. Consultar al Asistente de IA (Búsqueda)
# 4. Salir del sistema
# ...
# Elige una opción (1-4): 1
#
# --- 📝 REGISTRO DE NUEVO ESTILISTA ---
# Nombre del estilista: Keyla
# Especialidad en color (ej. Balayage): Balayage
# Salón de belleza al que pertenece: MAJA
# Agenda semanal (ej. Lun-Vie 9-18): Lun-Vie
# Técnicas dominadas: cortes
# Marcas aliadas: Yosaki
# Premio's o reconocimientos: 10
#
# ✅ ¡IA: Estilista 'Keyla' registrado con éxito en el diccionario!
# ...
#       💇 CONSOLA DE INTELIGENCIA ARTIFICIAL 💇
#             'GLAMOUR DATA-ANALYTICS'
# ...
# 1. Registrar nuevo estilista
# 2. Mostrar tabla de estilistas (Alineada)
# 3. Consultar al Asistente de IA (Búsqueda)
# 4. Salir del sistema
# ...
# Elige una opción (1-4): 1
#
# --- 📝 REGISTRO DE NUEVO ESTILISTA ---
# Nombre del estilista: Alonso
# Especialidad en color (ej. Balayage): Melting
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/keylacigarroa128/-UIII-Act-11-Proyecto-de-simulaci-n-Keyla-Cigarroa-0033/refs/heads/main/infografiaact11.png)
